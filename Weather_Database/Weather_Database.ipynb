# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Import the datetime module from the datetime library.
from datetime import datetime
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        print(city_url)
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Description" : city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=east+london
# Processing Record 2 of Set 16 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kruisfontein
# Processing Record 3 of Set 16 | piney green
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=piney+green
# Processing Record 4 of Set 16 | kayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kayes
# Processing Record 5 of Set 16 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=busselton
# Processing Record 6 of Set 16 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 16 | madinat sittah uktubar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=madinat+sittah+uktubar
# Processing Record 8 of Set 16 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=henties+bay
# Processing Record 9 of Set 16 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=rikitea
# Processing Record 10 of Set 16 | portsmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=portsmouth
# Processing Record 11 of Set 16 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=general+roca
# Processing Record 12 of Set 16 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=vaini
# Processing Record 13 of Set 16 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=albany
# Processing Record 14 of Set 16 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=severo-kurilsk
# Processing Record 15 of Set 16 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=qaanaaq
# Processing Record 16 of Set 16 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kapaa
# Processing Record 17 of Set 16 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bethel
# Processing Record 18 of Set 16 | biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=biltine
# Processing Record 19 of Set 16 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=paamiut
# Processing Record 20 of Set 16 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bluff
# Processing Record 21 of Set 16 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=butaritari
# Processing Record 22 of Set 16 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=eureka
# Processing Record 23 of Set 16 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=jamestown
# Processing Record 24 of Set 16 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mataura
# Processing Record 25 of Set 16 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=carnarvon
# Processing Record 26 of Set 16 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=castro
# Processing Record 27 of Set 16 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 16 | yakima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=yakima
# Processing Record 29 of Set 16 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=noumea
# Processing Record 30 of Set 16 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hilo
# Processing Record 31 of Set 16 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kavieng
# Processing Record 32 of Set 16 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bonthe
# Processing Record 33 of Set 16 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=adrar
# Processing Record 34 of Set 16 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ushuaia
# Processing Record 35 of Set 16 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=puerto+ayora
# Processing Record 36 of Set 16 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kaitangata
# Processing Record 37 of Set 16 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=avarua
# Processing Record 38 of Set 16 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bredasdorp
# Processing Record 39 of Set 16 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nikolskoye
# Processing Record 40 of Set 16 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=vangaindrano
# Processing Record 41 of Set 16 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=pundaguitan
# Processing Record 42 of Set 16 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=upernavik
# Processing Record 43 of Set 16 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=port+lincoln
# Processing Record 44 of Set 16 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=grand+river+south+east
# City not found. Skipping...
# Processing Record 45 of Set 16 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lulea
# Processing Record 46 of Set 16 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mar+del+plata
# Processing Record 47 of Set 16 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=punta+arenas
# Processing Record 48 of Set 16 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=coos+bay
# Processing Record 49 of Set 16 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sitka
# Processing Record 50 of Set 16 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=cam+ranh
# Processing Record 1 of Set 17 | trebechovice pod orebem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=trebechovice+pod+orebem
# Processing Record 2 of Set 17 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=asau
# Processing Record 3 of Set 17 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=manggar
# Processing Record 4 of Set 17 | kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kargasok
# Processing Record 5 of Set 17 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=plettenberg+bay
# Processing Record 6 of Set 17 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=constitucion
# Processing Record 7 of Set 17 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=cape+town
# Processing Record 8 of Set 17 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=samusu
# City not found. Skipping...
# Processing Record 9 of Set 17 | maloshuyka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 17 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mandalgovi
# Processing Record 11 of Set 17 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sambava
# Processing Record 12 of Set 17 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tuatapere
# Processing Record 13 of Set 17 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=chuy
# Processing Record 14 of Set 17 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hermanus
# Processing Record 15 of Set 17 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=airai
# Processing Record 16 of Set 17 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hobart
# Processing Record 17 of Set 17 | weyburn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=weyburn
# Processing Record 18 of Set 17 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=fairbanks
# Processing Record 19 of Set 17 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lebu
# Processing Record 20 of Set 17 | kjopsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kjopsvik
# Processing Record 21 of Set 17 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=luderitz
# Processing Record 22 of Set 17 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=provideniya
# Processing Record 23 of Set 17 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 17 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=faanui
# Processing Record 25 of Set 17 | riverton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=riverton
# Processing Record 26 of Set 17 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=dingle
# Processing Record 27 of Set 17 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=halalo
# City not found. Skipping...
# Processing Record 28 of Set 17 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=praia
# Processing Record 29 of Set 17 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=prince+rupert
# Processing Record 30 of Set 17 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=atuona
# Processing Record 31 of Set 17 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 17 | lipari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lipari
# Processing Record 33 of Set 17 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=vysokogornyy
# Processing Record 34 of Set 17 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hofn
# Processing Record 35 of Set 17 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=codrington
# Processing Record 36 of Set 17 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tuktoyaktuk
# Processing Record 37 of Set 17 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=burnie
# Processing Record 38 of Set 17 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=poum
# Processing Record 39 of Set 17 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tazovskiy
# Processing Record 40 of Set 17 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=meulaboh
# Processing Record 41 of Set 17 | gouyave
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=gouyave
# Processing Record 42 of Set 17 | jaipur hat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=jaipur+hat
# City not found. Skipping...
# Processing Record 43 of Set 17 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ahuimanu
# Processing Record 44 of Set 17 | la palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=la+palma
# Processing Record 45 of Set 17 | kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kyzyl-suu
# Processing Record 46 of Set 17 | machali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=machali
# Processing Record 47 of Set 17 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 17 | tulum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tulum
# Processing Record 49 of Set 17 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bonavista
# Processing Record 50 of Set 17 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=zhigansk
# Processing Record 1 of Set 18 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kawalu
# Processing Record 2 of Set 18 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nome
# Processing Record 3 of Set 18 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=san+patricio
# Processing Record 4 of Set 18 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=coquimbo
# Processing Record 5 of Set 18 | novaya lyada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=novaya+lyada
# Processing Record 6 of Set 18 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hasaki
# Processing Record 7 of Set 18 | krasnyy chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=krasnyy+chikoy
# Processing Record 8 of Set 18 | tenenkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tenenkou
# Processing Record 9 of Set 18 | kuche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kuche
# City not found. Skipping...
# Processing Record 10 of Set 18 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=pisco
# Processing Record 11 of Set 18 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ilulissat
# Processing Record 12 of Set 18 | norrtalje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=norrtalje
# Processing Record 13 of Set 18 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mehamn
# Processing Record 14 of Set 18 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tevaitoa
# Processing Record 15 of Set 18 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=inirida
# Processing Record 16 of Set 18 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sur
# Processing Record 17 of Set 18 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=geraldton
# Processing Record 18 of Set 18 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=neiafu
# Processing Record 19 of Set 18 | turkmenabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=turkmenabat
# Processing Record 20 of Set 18 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=narsaq
# Processing Record 21 of Set 18 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=port+hardy
# Processing Record 22 of Set 18 | sebastian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sebastian
# Processing Record 23 of Set 18 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=victoria
# Processing Record 24 of Set 18 | gidam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=gidam
# Processing Record 25 of Set 18 | shenzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=shenzhen
# Processing Record 26 of Set 18 | biograd na moru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=biograd+na+moru
# Processing Record 27 of Set 18 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=katsuura
# Processing Record 28 of Set 18 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=yellowknife
# Processing Record 29 of Set 18 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=baykit
# Processing Record 30 of Set 18 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=moron
# Processing Record 31 of Set 18 | omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=omboue
# Processing Record 32 of Set 18 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=baruun-urt
# Processing Record 33 of Set 18 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=harper
# Processing Record 34 of Set 18 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=clyde+river
# Processing Record 35 of Set 18 | defiance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=defiance
# Processing Record 36 of Set 18 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kloulklubed
# Processing Record 37 of Set 18 | freeport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=freeport
# Processing Record 38 of Set 18 | attur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=attur
# Processing Record 39 of Set 18 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nhulunbuy
# Processing Record 40 of Set 18 | slave lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=slave+lake
# Processing Record 41 of Set 18 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=jiuquan
# Processing Record 42 of Set 18 | sao domingos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sao+domingos
# Processing Record 43 of Set 18 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=grindavik
# Processing Record 44 of Set 18 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=saskylakh
# Processing Record 45 of Set 18 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=yar-sale
# Processing Record 46 of Set 18 | junqueiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=junqueiro
# Processing Record 47 of Set 18 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=belyy+yar
# Processing Record 48 of Set 18 | karasjok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=karasjok
# Processing Record 49 of Set 18 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kudahuvadhoo
# Processing Record 50 of Set 18 | moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=moree
# Processing Record 1 of Set 19 | leninskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=leninskoye
# Processing Record 2 of Set 19 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=port+alfred
# Processing Record 3 of Set 19 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=luganville
# Processing Record 4 of Set 19 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=najran
# Processing Record 5 of Set 19 | beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=beisfjord
# Processing Record 6 of Set 19 | pondicherry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=pondicherry
# Processing Record 7 of Set 19 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=emerald
# Processing Record 8 of Set 19 | taperoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=taperoa
# Processing Record 9 of Set 19 | freetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=freetown
# Processing Record 10 of Set 19 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=la+ronge
# Processing Record 11 of Set 19 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nguiu
# City not found. Skipping...
# Processing Record 12 of Set 19 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=talnakh
# Processing Record 13 of Set 19 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=eydhafushi
# Processing Record 14 of Set 19 | toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=toamasina
# Processing Record 15 of Set 19 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hithadhoo
# Processing Record 16 of Set 19 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=cherskiy
# Processing Record 17 of Set 19 | el sauzal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=el+sauzal
# Processing Record 18 of Set 19 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=salalah
# Processing Record 19 of Set 19 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=karratha
# Processing Record 20 of Set 19 | collie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=collie
# Processing Record 21 of Set 19 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=port+keats
# Processing Record 22 of Set 19 | rio brilhante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=rio+brilhante
# Processing Record 23 of Set 19 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ancud
# Processing Record 24 of Set 19 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=thompson
# Processing Record 25 of Set 19 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lorengau
# Processing Record 26 of Set 19 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=saldanha
# Processing Record 27 of Set 19 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=matay
# Processing Record 28 of Set 19 | tulancingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tulancingo
# Processing Record 29 of Set 19 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=barrow
# Processing Record 30 of Set 19 | kommunisticheskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kommunisticheskiy
# Processing Record 31 of Set 19 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=naze
# Processing Record 32 of Set 19 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=torbay
# Processing Record 33 of Set 19 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=saint-pierre
# Processing Record 34 of Set 19 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=souillac
# Processing Record 35 of Set 19 | chunoyar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=chunoyar
# Processing Record 36 of Set 19 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=dikson
# Processing Record 37 of Set 19 | warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=warrington
# Processing Record 38 of Set 19 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 19 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=srednekolymsk
# Processing Record 40 of Set 19 | aktau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=aktau
# Processing Record 41 of Set 19 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=new+norfolk
# Processing Record 42 of Set 19 | tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tucuman
# Processing Record 43 of Set 19 | nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nouakchott
# Processing Record 44 of Set 19 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=port+blair
# Processing Record 45 of Set 19 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=arraial+do+cabo
# Processing Record 46 of Set 19 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ambon
# Processing Record 47 of Set 19 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=rio+gallegos
# Processing Record 48 of Set 19 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=northam
# Processing Record 49 of Set 19 | soe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=soe
# Processing Record 50 of Set 19 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nicoya
# Processing Record 1 of Set 20 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=along
# Processing Record 2 of Set 20 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tiksi
# Processing Record 3 of Set 20 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=rio+grande
# Processing Record 4 of Set 20 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=qaqortoq
# Processing Record 5 of Set 20 | ovalle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ovalle
# Processing Record 6 of Set 20 | carhuaz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=carhuaz
# Processing Record 7 of Set 20 | labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=labutta
# City not found. Skipping...
# Processing Record 8 of Set 20 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tasiilaq
# Processing Record 9 of Set 20 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=san+rafael
# Processing Record 10 of Set 20 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=pevek
# Processing Record 11 of Set 20 | weihai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=weihai
# Processing Record 12 of Set 20 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=la+asuncion
# Processing Record 13 of Set 20 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=vila+velha
# Processing Record 14 of Set 20 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=chokurdakh
# Processing Record 15 of Set 20 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=xai-xai
# Processing Record 16 of Set 20 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bubaque
# Processing Record 17 of Set 20 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=alta+floresta
# Processing Record 18 of Set 20 | gunjur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=gunjur
# Processing Record 19 of Set 20 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sabang
# Processing Record 20 of Set 20 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=khatanga
# Processing Record 21 of Set 20 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=port-gentil
# Processing Record 22 of Set 20 | jabiru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=jabiru
# City not found. Skipping...
# Processing Record 23 of Set 20 | dunmore town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=dunmore+town
# Processing Record 24 of Set 20 | karsava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=karsava
# Processing Record 25 of Set 20 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=saint-philippe
# Processing Record 26 of Set 20 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=fare
# Processing Record 27 of Set 20 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kamenka
# Processing Record 28 of Set 20 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sao+joao+da+barra
# Processing Record 29 of Set 20 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=necochea
# Processing Record 30 of Set 20 | linqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=linqing
# Processing Record 31 of Set 20 | surt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=surt
# Processing Record 32 of Set 20 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hami
# Processing Record 33 of Set 20 | kalashnikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kalashnikovo
# Processing Record 34 of Set 20 | makuyuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=makuyuni
# Processing Record 35 of Set 20 | kilimatinde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kilimatinde
# Processing Record 36 of Set 20 | arroyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=arroyo
# Processing Record 37 of Set 20 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=abu+dhabi
# Processing Record 38 of Set 20 | parambu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=parambu
# Processing Record 39 of Set 20 | durant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=durant
# Processing Record 40 of Set 20 | osorno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=osorno
# Processing Record 41 of Set 20 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=whitehorse
# Processing Record 42 of Set 20 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=coihaique
# Processing Record 43 of Set 20 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bambous+virieux
# Processing Record 44 of Set 20 | diplo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=diplo
# Processing Record 45 of Set 20 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ostrovnoy
# Processing Record 46 of Set 20 | pinega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=pinega
# Processing Record 47 of Set 20 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=cidreira
# Processing Record 48 of Set 20 | cilegon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=cilegon
# Processing Record 49 of Set 20 | kasungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kasungu
# Processing Record 50 of Set 20 | farias brito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=farias+brito
# Processing Record 1 of Set 21 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=laguna
# Processing Record 2 of Set 21 | lar gerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lar+gerd
# City not found. Skipping...
# Processing Record 3 of Set 21 | urusha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=urusha
# Processing Record 4 of Set 21 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sorland
# Processing Record 5 of Set 21 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sobolevo
# Processing Record 6 of Set 21 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=opuwo
# Processing Record 7 of Set 21 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=husavik
# Processing Record 8 of Set 21 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mitsamiouli
# Processing Record 9 of Set 21 | krasnoarmeysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=krasnoarmeysk
# Processing Record 10 of Set 21 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=viedma
# Processing Record 11 of Set 21 | itaparica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=itaparica
# Processing Record 12 of Set 21 | kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kitimat
# Processing Record 13 of Set 21 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 21 | guarapari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=guarapari
# Processing Record 15 of Set 21 | matamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=matamoros
# Processing Record 16 of Set 21 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=acapulco
# Processing Record 17 of Set 21 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=saint+george
# Processing Record 18 of Set 21 | anton lizardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=anton+lizardo
# Processing Record 19 of Set 21 | malanville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=malanville
# Processing Record 20 of Set 21 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 21 | tibati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tibati
# Processing Record 22 of Set 21 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=belushya+guba
# City not found. Skipping...
# Processing Record 23 of Set 21 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ulaangom
# Processing Record 24 of Set 21 | sujiatun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sujiatun
# Processing Record 25 of Set 21 | glenwood springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=glenwood+springs
# Processing Record 26 of Set 21 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nishihara
# Processing Record 27 of Set 21 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lazaro+cardenas
# Processing Record 28 of Set 21 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=portland
# Processing Record 29 of Set 21 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=keti+bandar
# Processing Record 30 of Set 21 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=meyungs
# City not found. Skipping...
# Processing Record 31 of Set 21 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=iqaluit
# Processing Record 32 of Set 21 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nantucket
# Processing Record 33 of Set 21 | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kjollefjord
# Processing Record 34 of Set 21 | gobabis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=gobabis
# Processing Record 35 of Set 21 | barra patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=barra+patuca
# Processing Record 36 of Set 21 | nikolayevsk-na-amure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nikolayevsk-na-amure
# Processing Record 37 of Set 21 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=saint-francois
# Processing Record 38 of Set 21 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=college
# Processing Record 39 of Set 21 | martaban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=martaban
# Processing Record 40 of Set 21 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=cabo+san+lucas
# Processing Record 41 of Set 21 | nicolas bravo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nicolas+bravo
# Processing Record 42 of Set 21 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kununurra
# Processing Record 43 of Set 21 | baoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=baoro
# Processing Record 44 of Set 21 | santarem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=santarem
# Processing Record 45 of Set 21 | vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=vaitape
# Processing Record 46 of Set 21 | bien hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bien+hoa
# Processing Record 47 of Set 21 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=aswan
# Processing Record 48 of Set 21 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=padang
# Processing Record 49 of Set 21 | nizhnyaya pavlovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=nizhnyaya+pavlovka
# City not found. Skipping...
# Processing Record 50 of Set 21 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ponta+do+sol
# Processing Record 1 of Set 22 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=erzin
# Processing Record 2 of Set 22 | masalli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=masalli
# Processing Record 3 of Set 22 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=udachnyy
# Processing Record 4 of Set 22 | exu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=exu
# Processing Record 5 of Set 22 | outram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=outram
# Processing Record 6 of Set 22 | bengkulu
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=malakal
# Processing Record 17 of Set 29 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=berlevag
# Processing Record 18 of Set 29 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=inhambane
# Processing Record 19 of Set 29 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=leh
# Processing Record 20 of Set 29 | la libertad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=la+libertad
# Processing Record 21 of Set 29 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=chara
# Processing Record 22 of Set 29 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=labuhan
# Processing Record 23 of Set 29 | balakhta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=balakhta
# Processing Record 24 of Set 29 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=waipawa
# Processing Record 25 of Set 29 | hanstholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hanstholm
# Processing Record 26 of Set 29 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mogadishu
# Processing Record 27 of Set 29 | ouango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ouango
# Processing Record 28 of Set 29 | lages
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lages
# Processing Record 29 of Set 29 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ulladulla
# Processing Record 30 of Set 29 | vinukonda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=vinukonda
# Processing Record 31 of Set 29 | paso de los toros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=paso+de+los+toros
# Processing Record 32 of Set 29 | lokossa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lokossa
# Processing Record 33 of Set 29 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=isangel
# Processing Record 34 of Set 29 | clarence town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=clarence+town
# Processing Record 35 of Set 29 | kasamatsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kasamatsu
# Processing Record 36 of Set 29 | chokwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=chokwe
# Processing Record 37 of Set 29 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=svetlyy
# Processing Record 38 of Set 29 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=makakilo+city
# Processing Record 39 of Set 29 | basar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=basar
# Processing Record 40 of Set 29 | hukuntsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hukuntsi
# Processing Record 41 of Set 29 | chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=chikoy
# City not found. Skipping...
# Processing Record 42 of Set 29 | rouvroy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=rouvroy
# Processing Record 43 of Set 29 | sibiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sibiti
# Processing Record 44 of Set 29 | rognan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=rognan
# Processing Record 45 of Set 29 | agadir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=agadir
# Processing Record 46 of Set 29 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=la+rioja
# Processing Record 47 of Set 29 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bayir
# Processing Record 48 of Set 29 | lago da pedra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lago+da+pedra
# Processing Record 49 of Set 29 | horodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=horodok
# Processing Record 50 of Set 29 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mahibadhoo
# Processing Record 1 of Set 30 | qobustan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=qobustan
# Processing Record 2 of Set 30 | buariki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=buariki
# City not found. Skipping...
# Processing Record 3 of Set 30 | suclayin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=suclayin
# Processing Record 4 of Set 30 | south river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=south+river
# Processing Record 5 of Set 30 | petropavlovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=petropavlovka
# Processing Record 6 of Set 30 | atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=atambua
# Processing Record 7 of Set 30 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=margate
# Processing Record 8 of Set 30 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=flinders
# Processing Record 9 of Set 30 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=araouane
# Processing Record 10 of Set 30 | barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=barguzin
# Processing Record 11 of Set 30 | betare oya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=betare+oya
# Processing Record 12 of Set 30 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=finschhafen
# Processing Record 13 of Set 30 | lugo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=lugo
# Processing Record 14 of Set 30 | talagang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=talagang
# Processing Record 15 of Set 30 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=klaksvik
# Processing Record 16 of Set 30 | hallingby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hallingby
# City not found. Skipping...
# Processing Record 17 of Set 30 | brits
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=brits
# Processing Record 18 of Set 30 | gopalpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=gopalpur
# Processing Record 19 of Set 30 | skagastrond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 30 | kinna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kinna
# Processing Record 21 of Set 30 | shangqiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=shangqiu
# Processing Record 22 of Set 30 | reshetylivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=reshetylivka
# Processing Record 23 of Set 30 | ryde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ryde
# Processing Record 24 of Set 30 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=bud
# Processing Record 25 of Set 30 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mercedes
# Processing Record 26 of Set 30 | keflavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=keflavik
# Processing Record 27 of Set 30 | tinnanur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tinnanur
# Processing Record 28 of Set 30 | narimanov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=narimanov
# Processing Record 29 of Set 30 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ust-nera
# Processing Record 30 of Set 30 | kalemie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kalemie
# Processing Record 31 of Set 30 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=umm+kaddadah
# Processing Record 32 of Set 30 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=palauig
# Processing Record 33 of Set 30 | otofuke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=otofuke
# Processing Record 34 of Set 30 | pacora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=pacora
# Processing Record 35 of Set 30 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ranong
# Processing Record 36 of Set 30 | kleck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kleck
# City not found. Skipping...
# Processing Record 37 of Set 30 | greenville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=greenville
# Processing Record 38 of Set 30 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=khonuu
# City not found. Skipping...
# Processing Record 39 of Set 30 | rosetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=rosetta
# Processing Record 40 of Set 30 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=puerto+carreno
# Processing Record 41 of Set 30 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=tateyama
# Processing Record 42 of Set 30 | wucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=wucheng
# Processing Record 43 of Set 30 | wageningen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=wageningen
# Processing Record 44 of Set 30 | torgelow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=torgelow
# Processing Record 45 of Set 30 | gander
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=gander
# Processing Record 46 of Set 30 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=san+policarpo
# Processing Record 47 of Set 30 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mareeba
# Processing Record 48 of Set 30 | mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mehran
# Processing Record 49 of Set 30 | silver city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=silver+city
# Processing Record 50 of Set 30 | ballstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=ballstad
# City not found. Skipping...
# Processing Record 1 of Set 31 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=celestun
# Processing Record 2 of Set 31 | barawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=barawe
# City not found. Skipping...
# Processing Record 3 of Set 31 | grandview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=grandview
# Processing Record 4 of Set 31 | kochki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kochki
# Processing Record 5 of Set 31 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=korla
# Processing Record 6 of Set 31 | birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=birao
# Processing Record 7 of Set 31 | mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=mezen
# Processing Record 8 of Set 31 | baza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=baza
# Processing Record 9 of Set 31 | hvammstangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=hvammstangi
# City not found. Skipping...
# Processing Record 10 of Set 31 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=beyneu
# Processing Record 11 of Set 31 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=pangnirtung
# Processing Record 12 of Set 31 | irbit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=irbit
# Processing Record 13 of Set 31 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=itarema
# Processing Record 14 of Set 31 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=sorong
# Processing Record 15 of Set 31 | casa nova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=casa+nova
# Processing Record 16 of Set 31 | salisbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=salisbury
# Processing Record 17 of Set 31 | kurumkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kurumkan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             East London -33.0153   27.9116     54.54       100         100
# 1            Kruisfontein -34.0033   24.7314     51.89        74          88
# 2             Piney Green  34.7160  -77.3202     81.18        94          75
# 3                   Kayes  14.0000  -11.0000     84.02        70          72
# 4               Busselton -33.6500  115.3333     50.43        81          28
# 5  Madinat Sittah Uktubar  29.8167   31.0500     89.20        30           0
# 6             Henties Bay -22.1160   14.2845     56.59        77           0
# 7                 Rikitea -23.1203 -134.9692     71.92        82          85
# 8              Portsmouth  50.7990   -1.0913     75.00        68          98
# 9            General Roca -39.0333  -67.5833     64.62        14          60
#
#    Wind Speed Country       Description
# 0       16.11      ZA              mist
# 1       17.07      ZA        light rain
# 2        0.00      US        light rain
# 3        8.77      ML        light rain
# 4        4.52      AU  scattered clouds
# 5       14.65      EG         clear sky
# 6       10.83      NA         clear sky
# 7       15.66      PF   overcast clouds
# 8        8.01      GB   overcast clouds
# 9       20.04      AR     broken clouds

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cc73567ca04a213a67034d5e8202e89c&q=kurumkan

# %%
# Arrange Columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# %%
# Updated Data Frame
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0             East London      ZA -33.0153   27.9116     54.54       100
# 1            Kruisfontein      ZA -34.0033   24.7314     51.89        74
# 2             Piney Green      US  34.7160  -77.3202     81.18        94
# 3                   Kayes      ML  14.0000  -11.0000     84.02        70
# 4               Busselton      AU -33.6500  115.3333     50.43        81
# 5  Madinat Sittah Uktubar      EG  29.8167   31.0500     89.20        30
# 6             Henties Bay      NA -22.1160   14.2845     56.59        77
# 7                 Rikitea      PF -23.1203 -134.9692     71.92        82
# 8              Portsmouth      GB  50.7990   -1.0913     75.00        68
# 9            General Roca      AR -39.0333  -67.5833     64.62        14
#
#    Cloudiness  Wind Speed       Description
# 0         100       16.11              mist
# 1          88       17.07        light rain
# 2          75        0.00        light rain
# 3          72        8.77        light rain
# 4          28        4.52  scattered clouds
# 5           0       14.65         clear sky
# 6           0       10.83         clear sky
# 7          85       15.66   overcast clouds
# 8          98        8.01   overcast clouds
# 9          60       20.04     broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
